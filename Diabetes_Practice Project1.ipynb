# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv("D:\PYTHON\python2\diabetes2.csv")

# %%
a.shape
# Out:
# (768, 9)

# %%
a.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
a.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
b=a.corr()
b
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
corr=a.corr()
r = sns.heatmap(corr,cmap='winter')
r.set_title("Correlation")
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
corr.sort_values(by=['BloodPressure'],ascending=False)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# BMI                          0.017683  0.221071       0.281805       0.392573
# Age                          0.544341  0.263514       0.239528      -0.113970
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Glucose                      0.129459  1.000000       0.152590       0.057328
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# Outcome                      0.221898  0.466581       0.065068       0.074752
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# BloodPressure             0.088933  0.281805                  0.041265
# ...

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Pregnancies',y='Outcome',data=a)
plt.title('Relation of pregnancies and Outcome')
plt.show()

# %%
labels = ['BloodPressure','No BloodPressure']
values=a['Outcome'].value_counts().values
fig,ax1=plt.subplots()
colors=['red','lightskyblue']
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
labels = ['Dibetes','No Dibetes']
values = a['Outcome'].value_counts().values
fig1, ax1= plt.subplots()
colors = ['lightgreen','lightskyblue']
ax1.pie(values,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90,colors=colors)
plt.show()

# %%
plt.figure(figsize=(10,6))
a['Pregnancies'].hist(alpha=0.5,color='lightgreen',label='Pregnancies')
a['Age'].hist(alpha=0.5,color='red',label='Age')
plt.legend()
plt.xlabel('Outcome')
# Out:
# Text(0.5, 0, 'Outcome')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.svm import SVC

# %%
scaler = StandardScaler()
x = a.drop('Outcome',axis=1)
y = a['Outcome'] 

scaler.fit(x)
x_transformed = scaler.transform(x)
x_train,x_test,y_train,y_test = train_test_split(x_transformed,y,test_size=0.3)

# %%
model=SVC()
x=a.drop('Outcome',axis=1)
y=a['Outcome']
x_transformed=scaler.transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_transformed,y,test_size=0.22,random_state=16)

# %%
model = SVC() 
model.fit(x_train,y_train)

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)


print("Train Set Accuracy:"+str(accuracy_score(y_train_pred,y_train)*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test_pred,y_test)*100))
print("\nConfusion Matrix:\n%s"%confusion_matrix(y_test_pred,y_test))
print("\nClassificationReport:\n%s"%classification_report(y_test_pred,y_test))
# Out:
# Train Set Accuracy:82.47078464106845
# Test Set Accuracy:80.4733727810651
#
# Confusion Matrix:
# [[101  22]
#  [ 11  35]]
#
# ClassificationReport:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86       123
#            1       0.61      0.76      0.68        46
#
#     accuracy                           0.80       169
#    macro avg       0.76      0.79      0.77       169
# weighted avg       0.82      0.80      0.81       169
